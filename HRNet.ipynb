# %%
from fastai.basics import *
from fastai.vision import models
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *
from fastai.callback import *

# SemTorch
from semtorch import get_segmentation_learner

from pathlib import Path
import random
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
import torch
torch.cuda.set_device(0)

# %%
# %matplotlib inline
import numpy as np

# %% [markdown]
# Function por stablishing the seed for reproducibility

# %%
number_of_the_seed = 2020

random.seed(number_of_the_seed)
set_seed(number_of_the_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
path = Path("dataset/")
path_images = path/"Images"
path_labels = path/"Labels"

test_name = "test"

# %% [markdown]
# Obtaining the label associated with an image, in the case of segmentation it is a mask

# %%
get_y_fn = lambda x: Path(str(x).replace("Images","Labels").replace("color","gt").replace(".jpg",".png"))

# %% [markdown]
# Aux function for splitting between training and testing

# %%
def ParentSplitter(x):
    return Path(x).parent.name==test_name

# %% [markdown]
# Loading the codes of the different classes. All the datasets have the same codes.

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str)

# %%
def msa(input, target):
    target = target.squeeze(1)
    mask = target != -1
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def background(input, target):
    target = target.squeeze(1)
    mask = target != 0
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def leaves(input, target):
    target = target.squeeze(1)
    mask = target != 1
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def wood(input, target):
    target = target.squeeze(1)
    mask = target != 2
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def pole(input, target):
    target = target.squeeze(1)
    mask = target != 3
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def grape(input, target):
    target = target.squeeze(1)
    mask = target != 4
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %% [markdown]
# Early Stopping parameters

# %%
monitor_training="valid_loss"
comp_training=np.less

monitor_evaluating="dice"
comp_evaluating=np.greater

patience=2

# %%
from albumentations import (
    Compose,
    OneOf,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    Flip,
    Rotate,
    Transpose,
    CLAHE,
    ShiftScaleRotate
)

# %%
class SegmentationAlbumentationsTransform(ItemTransform):
    split_idx = 0
    def __init__(self, aug): 
        self.aug = aug
    def encodes(self, x):
        img,mask = x
        aug = self.aug(image=np.array(img), mask=np.array(mask))
        return PILImage.create(aug["image"]), PILMask.create(aug["mask"])
    
transformPipeline=Compose([
                        Flip(p=0.5),
                        Transpose(p=0.5),
                        Rotate(p=0.40,limit=10),GridDistortion()
                    ],p=1)

transformPipeline=SegmentationAlbumentationsTransform(transformPipeline)

# %%
class TargetMaskConvertTransform(ItemTransform):
    def __init__(self): 
        pass
    def encodes(self, x):
        img,mask = x
        
        #Convert to array
        mask = np.array(mask)
        
        # Change 255 for 4
        mask[mask==255]=4
        mask[mask==150]=1
        mask[mask==76]=3
        mask[mask==74]=3
        mask[mask==29]=2
        mask[mask==25]=2
        
        # Back to PILMask
        mask = PILMask.create(mask)
        return img, mask

# %%
path_manual_img = path_images/'train'
path_manual_lbl = path_labels/'train'

# %%
fnames_manual = get_image_files(path_manual_img)
lbl_names_manual = get_image_files(path_manual_lbl)

# open and show image
img_f = fnames_manual[10]
print(img_f)
img = PILImage.create(img_f)
img.show(figsize=(5, 5))
# Out:
# dataset/Images/train/color_159.jpg
# <AxesSubplot:>

# %%
print(get_y_fn(img_f))
# Out:
# dataset/Labels/train/gt_159.png

# %%
mask = PILMask.create(get_y_fn(img_f))
mask.show(figsize=(5, 5), alpha=1)
# Out:
# <AxesSubplot:>

# %%
np.unique(np.array(mask))
# Out:
# array([  0,  29,  76, 150, 255], dtype=uint8)

# %%
bs = 4

# %%
codes
# Out:
# array(['Background', 'Leaves', 'Wood', 'Pole', 'Grape'], dtype='<U10')

# %%
??get_image_files

# %%
def my_get_items(folders,path):
    return (get_image_files(path))

# %%
manual = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files,folders=['train','test']),
                   get_y=get_y_fn,
                   splitter=FuncSplitter(ParentSplitter),
                   item_tfms=[Resize((640,640)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )
#manual.summary(path_images)
dls = manual.dataloaders(path_images,bs=bs)
#dls.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %%
#x,mask=dls.one_batch()

# %% [markdown]
# # HRNet

# %%
learn = get_segmentation_learner(dls=dls, number_classes=5, segmentation_type="Semantic Segmentation",
                                 architecture_name="hrnet", backbone_name="hrnet_w30", 
                                 metrics=[background,leaves,pole,grape,wood,msa],wd=1e-2,
                                 pretrained=True,normalize=True).to_fp16()

# %%
#learn.lr_find() # find learning rate
#learn.recorder # plot learning rate graph

# %%
fname="hrnet-before-unfreeze"

callbacksFitBeforeUnfreeze = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(20, slice(1e-5,1e-4),cbs=callbacksFitBeforeUnfreeze)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>background</th>
#       <th>leaves</th>
#       <th>pole</th>
#       <th>grape</th>
#       <th>wood</th>
#       <th>msa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.628155</td>
#       <td>1.658089</td>
#       <td>0.040102</td>
#       <td>0.069931</td>
#       <td>0.038938</td>
#       <td>0.040735</td>
#       <td>0.026589</td>
#       <td>0.040898</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.438709</td>
#       <td>1.540776</td>
#       <td>0.801652</td>
#       <td>0.215231</td>
#       <td>0.494381</td>
#       <td>0.493677</td>
#       <td>0.487999</td>
#       <td>0.490507</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.158042</td>
#       <td>1.316132</td>
#       <td>0.903791</td>
#       <td>0.386621</td>
#       <td>0.651729</td>
#       <td>0.648832</td>
#       <td>0.652053</td>
#       <td>0.644739</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.917914</td>
#       <td>1.390841</td>
#       <td>0.914172</td>
#       <td>0.334935</td>
#       <td>0.620816</td>
#       <td>0.613167</td>
#       <td>0.623030</td>
#       <td>0.614837</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.736244</td>
#       <td>1.293968</td>
#       <td>0.908133</td>
#       <td>0.377077</td>
#       <td>0.636541</td>
#       <td>0.628387</td>
#       <td>0.640681</td>
#       <td>0.632237</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.610770</td>
#       <td>1.185372</td>
#       <td>0.911497</td>
#       <td>0.447338</td>
#       <td>0.671252</td>
#       <td>0.664936</td>
#       <td>0.673211</td>
#       <td>0.668469</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.519947</td>
#       <td>1.170031</td>
#       <td>0.924580</td>
#       <td>0.431166</td>
#       <td>0.667372</td>
#       <td>0.661501</td>
#       <td>0.669734</td>
#       <td>0.664892</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.450453</td>
#       <td>0.976432</td>
#       <td>0.913259</td>
#       <td>0.574478</td>
#       <td>0.741565</td>
#       <td>0.736380</td>
#       <td>0.744076</td>
#       <td>0.738922</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.397323</td>
#       <td>0.941263</td>
#       <td>0.927859</td>
#       <td>0.574327</td>
#       <td>0.745130</td>
#       <td>0.741022</td>
#       <td>0.747096</td>
#       <td>0.743376</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.364082</td>
#       <td>0.735647</td>
#       <td>0.908531</td>
#       <td>0.706132</td>
#       <td>0.812031</td>
#       <td>0.808595</td>
#       <td>0.815616</td>
#       <td>0.809696</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.333084</td>
#       <td>0.819501</td>
#       <td>0.929917</td>
#       <td>0.615320</td>
#       <td>0.771711</td>
#       <td>0.767974</td>
#       <td>0.776329</td>
#       <td>0.770055</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.308574</td>
#       <td>0.648580</td>
#       <td>0.921330</td>
#       <td>0.706069</td>
#       <td>0.817951</td>
#       <td>0.815122</td>
#       <td>0.821708</td>
#       <td>0.815789</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.288630</td>
#       <td>0.613481</td>
#       <td>0.918105</td>
#       <td>0.710125</td>
#       <td>0.817680</td>
#       <td>0.814387</td>
#       <td>0.820667</td>
#       <td>0.815484</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.272604</td>
#       <td>0.589518</td>
#       <td>0.918748</td>
#       <td>0.714695</td>
#       <td>0.821257</td>
#       <td>0.818757</td>
#       <td>0.824421</td>
#       <td>0.818960</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.262413</td>
#       <td>0.533784</td>
#       <td>0.913939</td>
#       <td>0.729223</td>
#       <td>0.828750</td>
#       <td>0.826551</td>
#       <td>0.832175</td>
#       <td>0.826073</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.253223</td>
#       <td>0.510769</td>
#       <td>0.913849</td>
#       <td>0.728914</td>
#       <td>0.829567</td>
#       <td>0.827397</td>
#       <td>0.834596</td>
#       <td>0.827032</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.244222</td>
#       <td>0.504454</td>
#       <td>0.912294</td>
#       <td>0.728653</td>
#       <td>0.829066</td>
#       <td>0.826538</td>
#       <td>0.834249</td>
#       <td>0.826373</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.239607</td>
#       <td>0.482105</td>
#       <td>0.907714</td>
#       <td>0.741008</td>
#       <td>0.834199</td>
#       <td>0.831817</td>
#       <td>0.839226</td>
#       <td>0.831378</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.234771</td>
#       <td>0.475072</td>
#       <td>0.907533</td>
#       <td>0.740629</td>
#       <td>0.834191</td>
#       <td>0.831924</td>
#       <td>0.839312</td>
#       <td>0.831360</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.229554</td>
#       <td>0.469418</td>
#       <td>0.907131</td>
#       <td>0.740319</td>
#       <td>0.834132</td>
#       <td>0.832059</td>
#       <td>0.839373</td>
#       <td>0.831304</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Better model found at epoch 0 with valid_loss value: 1.6580885648727417.
# Better model found at epoch 1 with valid_loss value: 1.5407758951187134.
# Better model found at epoch 2 with valid_loss value: 1.3161324262619019.
# Better model found at epoch 4 with valid_loss value: 1.2939682006835938.
# Better model found at epoch 5 with valid_loss value: 1.185372233390808.
# Better model found at epoch 6 with valid_loss value: 1.170030951499939.
# Better model found at epoch 7 with valid_loss value: 0.9764319658279419.
# Better model found at epoch 8 with valid_loss value: 0.9412629008293152.
# Better model found at epoch 9 with valid_loss value: 0.7356471419334412.
# Better model found at epoch 11 with valid_loss value: 0.648580014705658.
# Better model found at epoch 12 with valid_loss value: 0.6134809255599976.
# Better model found at epoch 13 with valid_loss value: 0.5895175337791443.
# Better model found at epoch 14 with valid_loss value: 0.5337841510772705.
# Better model found at epoch 15 with valid_loss value: 0.5107694864273071.
# Better model found at epoch 16 with valid_loss value: 0.504454493522644.
# Better model found at epoch 17 with valid_loss value: 0.4821045994758606.
# Better model found at epoch 18 with valid_loss value: 0.47507235407829285.
# Better model found at epoch 19 with valid_loss value: 0.4694175720214844.

# %%
learn.load("hrnet-before-unfreeze")
learn.unfreeze()
#learn.lr_find() # find learning rate
#learn.recorder # plot learning rate graph

# %%
fname="hrnet-after-unfreeze"


callbacksFitAfterUnfreeze = [
    ShowGraphCallback(),
    EarlyStoppingCallback(monitor=monitor_training,comp=comp_training, patience=patience),
    SaveModelCallback(monitor=monitor_training,comp=comp_training,every_epoch=False,fname=fname)  
]
learn.fit_one_cycle(20, slice(1e-7,1e-7),cbs=callbacksFitAfterUnfreeze)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>background</th>
#       <th>leaves</th>
#       <th>pole</th>
#       <th>grape</th>
#       <th>wood</th>
#       <th>msa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.227303</td>
#       <td>0.464449</td>
#       <td>0.906516</td>
#       <td>0.740969</td>
#       <td>0.834481</td>
#       <td>0.832542</td>
#       <td>0.839791</td>
#       <td>0.831628</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.224670</td>
#       <td>0.461341</td>
#       <td>0.905989</td>
#       <td>0.740478</td>
#       <td>0.834273</td>
#       <td>0.832451</td>
#       <td>0.839654</td>
#       <td>0.831387</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.219999</td>
#       <td>0.457823</td>
#       <td>0.905391</td>
#       <td>0.740886</td>
#       <td>0.834411</td>
#       <td>0.832707</td>
#       <td>0.839863</td>
#       <td>0.831523</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.221182</td>
#       <td>0.455839</td>
#       <td>0.905030</td>
#       <td>0.740593</td>
#       <td>0.834210</td>
#       <td>0.832661</td>
#       <td>0.839741</td>
#       <td>0.831343</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.220510</td>
#       <td>0.454024</td>
#       <td>0.904550</td>
#       <td>0.740588</td>
#       <td>0.834175</td>
#       <td>0.832734</td>
#       <td>0.839753</td>
#       <td>0.831300</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.220591</td>
#       <td>0.452107</td>
#       <td>0.904088</td>
#       <td>0.741269</td>
#       <td>0.834442</td>
#       <td>0.833066</td>
#       <td>0.840026</td>
#       <td>0.831554</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.220208</td>
#       <td>0.453284</td>
#       <td>0.904559</td>
#       <td>0.739245</td>
#       <td>0.833691</td>
#       <td>0.832388</td>
#       <td>0.839299</td>
#       <td>0.830800</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.222299</td>
#       <td>0.452566</td>
#       <td>0.904223</td>
#       <td>0.739314</td>
#       <td>0.833747</td>
#       <td>0.832474</td>
#       <td>0.839388</td>
#       <td>0.830833</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.464449405670166.
# Better model found at epoch 1 with valid_loss value: 0.4613405168056488.
# Better model found at epoch 2 with valid_loss value: 0.4578229784965515.
# Better model found at epoch 3 with valid_loss value: 0.45583876967430115.
# Better model found at epoch 4 with valid_loss value: 0.4540240466594696.
# Better model found at epoch 5 with valid_loss value: 0.4521074593067169.
# No improvement since epoch 5: early stopping

# %%
learn.validate()
# Out:
# (#7) [0.4521074593067169,0.9040879011154175,0.7412686944007874,0.8344421982765198,0.8330658674240112,0.8400258421897888,0.83155357837677]

# %%
learn.show_results(figsize=(10,10))

# %%
aux=learn.model
aux=aux.cpu()

traced_cell=torch.jit.script(aux)
traced_cell.save("hrnet.pth")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# HRNet

model = torch.jit.load("hrnet.pth")
model = model.cpu()
model.eval()
# Out:
# RecursiveScriptModule(
#   original_name=HRNet
#   (backbone): RecursiveScriptModule(
#     original_name=HighResolutionNet
#     (conv1): RecursiveScriptModule(original_name=Conv2d)
#     (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#     (conv2): RecursiveScriptModule(original_name=Conv2d)
#     (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#     (relu): RecursiveScriptModule(original_name=ReLU)
#     (layer1): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=Bottleneck
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#         (downsample): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#         )
#       )
#       (1): RecursiveScriptModule(
#         original_name=Bottleneck
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=Bottleneck
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (3): RecursiveScriptModule(
#         original_name=Bottleneck
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#         (conv3): RecursiveScriptModule(original_name=Conv2d)
#         (bn3): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (transition1): RecursiveScriptModule(
#       original_name=ModuleList
#       (0): RecursiveScriptModule(
#         original_name=Sequential
#         (0): RecursiveScriptModule(original_name=Conv2d)
#         (1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (2): RecursiveScriptModule(original_name=ReLU)
#       )
#       (1): RecursiveScriptModule(
#         original_name=Sequential
#         (0): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#           (2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#     )
#     (stage2): RecursiveScriptModule(
#       original_name=ModuleList
#       (0): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#         )
#         (fuse_layers): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(original_name=Identity)
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (transition2): RecursiveScriptModule(
#       original_name=ModuleList
#       (0): RecursiveScriptModule(original_name=Identity)
#       (1): RecursiveScriptModule(original_name=Identity)
#       (2): RecursiveScriptModule(
#         original_name=Sequential
#         (0): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#           (2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#     )
#     (stage3): RecursiveScriptModule(
#       original_name=ModuleList
#       (0): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#         )
#         (fuse_layers): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(original_name=Identity)
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(original_name=Identity)
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (1): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#         )
#         (fuse_layers): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(original_name=Identity)
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(original_name=Identity)
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#         )
#         (fuse_layers): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(original_name=Identity)
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(original_name=Identity)
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (3): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#         )
#         (fuse_layers): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(original_name=Identity)
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(original_name=Identity)
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#     (transition3): RecursiveScriptModule(
#       original_name=ModuleList
#       (0): RecursiveScriptModule(original_name=Identity)
#       (1): RecursiveScriptModule(original_name=Identity)
#       (2): RecursiveScriptModule(original_name=Identity)
#       (3): RecursiveScriptModule(
#         original_name=Sequential
#         (0): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=BatchNorm2d)
#           (2): RecursiveScriptModule(original_name=ReLU)
#         )
#       )
#     )
#     (stage4): RecursiveScriptModule(
#       original_name=ModuleList
#       (0): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (3): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
# ...
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(original_name=Identity)
#             (3): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (3): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (2): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (3): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=HighResolutionModule
#         (branches): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (3): RecursiveScriptModule(
#             original_name=Sequential
#             (0): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (1): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=BasicBlock
#               (conv1): RecursiveScriptModule(original_name=Conv2d)
#               (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#               (relu): RecursiveScriptModule(original_name=ReLU)
#               (conv2): RecursiveScriptModule(original_name=Conv2d)
#               (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#         )
#         (fuse_layers): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(original_name=Identity)
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(original_name=Identity)
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#             (3): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(original_name=Identity)
#             (3): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(original_name=Conv2d)
#               (1): RecursiveScriptModule(original_name=BatchNorm2d)
#             )
#           )
#           (3): RecursiveScriptModule(
#             original_name=ModuleList
#             (0): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (2): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (1): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#                 (2): RecursiveScriptModule(original_name=ReLU)
#               )
#               (1): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (2): RecursiveScriptModule(
#               original_name=Sequential
#               (0): RecursiveScriptModule(
#                 original_name=Sequential
#                 (0): RecursiveScriptModule(original_name=Conv2d)
#                 (1): RecursiveScriptModule(original_name=BatchNorm2d)
#               )
#             )
#             (3): RecursiveScriptModule(original_name=Identity)
#           )
#         )
#         (relu): RecursiveScriptModule(original_name=ReLU)
#       )
#     )
#   )
#   (head): RecursiveScriptModule(
#     original_name=Sequential
#     (0): RecursiveScriptModule(original_name=Conv2d)
#     (1): RecursiveScriptModule(original_name=BatchNorm2d)
#     (2): RecursiveScriptModule(original_name=ReLU)
#     (3): RecursiveScriptModule(original_name=Conv2d)
#   )
# )

# %%
import torchvision.transforms as transforms
def transform_image(image):
    my_transforms = transforms.Compose([transforms.ToTensor(),
                                        transforms.Normalize(
                                            [0.485, 0.456, 0.406],
                                            [0.229, 0.224, 0.225])])
    image_aux = image
    return my_transforms(image_aux).unsqueeze(0).to(device)

# %%
image = Image.open('dataset/Images/test/color_154.jpg')

# %%
image = transforms.Resize((480,640))(image)
tensor = transform_image(image=image)

# %%
model.to(device)
with torch.no_grad():
    outputs = model(tensor)

outputs = torch.argmax(outputs,1)
# Out:
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# code/__torch__/torch/nn/functional/___torch_mangle_95.py:25: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.

# %%
outputs.to
# Out:
# <function Tensor.to>

# %%
mask = np.array(outputs.cpu())

# %%
mask[mask==4]=255
mask[mask==1]=150
mask[mask==3]=76
mask[mask==2]=29

# %%
mask=np.reshape(mask,(480,640))

# %%
maskShow = Image.fromarray(mask.astype('uint8'))
maskShow
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7FF6CC6A4908>

# %%
maskrgb = maskShow.convert('RGB')
maskrgb = np.array(maskrgb)
maskrgb[(maskrgb==[150,150,150]).all(axis=2)]=[0,255,0]
maskrgb[(maskrgb==[76,76,76]).all(axis=2)]=[255,0,0]
maskrgb[(maskrgb==[29,29,29]).all(axis=2)]=[0,0,255]

# %%
maskRGBShow = Image.fromarray(maskrgb.astype('uint8'))
maskRGBShow
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FF6CC6A46D8>

# %%
maskRGBShow.save('hrnet_pred_154.jpg')
